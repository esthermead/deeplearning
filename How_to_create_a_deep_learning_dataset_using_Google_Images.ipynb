# %% [markdown]
# <a href="https://colab.research.google.com/github/esthermead/deeplearning/blob/master/How_to_create_a_deep_learning_dataset_using_Google_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/
#for learning how to create my own image dataset to use for crowd counting.
#the first part of this is done in the JavaScript console of chrome (follow video on tut).
#this worked for me, but i moved my images folder to the CSRNet-pytorch folder so that i easier use it for crowd counting.

# %%
# click Runtime, select "change runtime", choose "GPU" accelaration.
# mount drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# change working directory to my DeepLearning folder
cd "/content/drive/My Drive/DeepLearning/generating_image_dataset"
# Out:
# /content/drive/My Drive/DeepLearning/generating_image_dataset

# %%
# !python download_images.py --urls urls-migrants.txt --output images/migrants
# Out:
# [INFO] downloaded: images/migrants/00000000.jpg
# [INFO] downloaded: images/migrants/00000001.jpg
# [INFO] downloaded: images/migrants/00000002.jpg
# [INFO] downloaded: images/migrants/00000003.jpg
# [INFO] downloaded: images/migrants/00000004.jpg
# [INFO] downloaded: images/migrants/00000005.jpg
# [INFO] downloaded: images/migrants/00000006.jpg
# [INFO] downloaded: images/migrants/00000007.jpg
# [INFO] downloaded: images/migrants/00000008.jpg
# [INFO] downloaded: images/migrants/00000009.jpg
# [INFO] downloaded: images/migrants/00000010.jpg
# [INFO] downloaded: images/migrants/00000011.jpg
# [INFO] downloaded: images/migrants/00000012.jpg
# [INFO] downloaded: images/migrants/00000013.jpg
# [INFO] downloaded: images/migrants/00000014.jpg
# [INFO] downloaded: images/migrants/00000015.jpg
# [INFO] downloaded: images/migrants/00000016.jpg
# [INFO] downloaded: images/migrants/00000017.jpg
# [INFO] downloaded: images/migrants/00000018.jpg
# [INFO] downloaded: images/migrants/00000019.jpg
# ...

# %%
#okay. this worked. again, the tut is from: https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/
# Out:
# '/content/drive/My Drive/DeepLearning/generating_image_dataset'
